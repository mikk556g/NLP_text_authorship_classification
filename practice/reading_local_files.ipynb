# %%
import os

# %%
f = open('text.txt')
raw = f.read()

# %%
f = open('text.txt')
f.read()
# Out:
# 'How much wood could a \nwoodchuck chug \nif a woodchuck could chug wood?'

# %%
# We can also read a file one line at a time using a for loop:
f = open('text.txt')
for line in f:
    print(line.strip())

# Here we use the strip() method to remove the newline character at the end of the input line.
# Out:
# How much wood could a
# woodchuck chug
# if a woodchuck could chug wood?
